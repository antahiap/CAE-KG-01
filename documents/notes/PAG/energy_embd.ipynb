# %%
# %matplotlib inline 


import sys
import os
import numpy as np
import matplotlib.pyplot as plt


norm_list = [
    "ie_tot_max",   # 0
    "ie_prt_max",   # 1
    "ke_tot_max",   # 2

    "ie_t0_ll",     # 3
    "t0_ll_pp",     # 4
    "ie_t0_grad",   # 5
    "t0_grad_pp",   # 6

    "ie_tn_pct",    # 7
    "tn_pct_max",   # 8
    "ie_tn_max",    # 9
    "tn_max_max"]   # 10

feat_list = [
    "nrg_max",  # 0

    "t0_grad",  # 1
    "t0_ll",    # 2

    "tn_pct",   # 3
    "tn_max"    # 4
    ]

sys.path.append('../../note_scripts')
import cypher_notebook_nrg as cy
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Projects/kg01/envs/lib/python3.6/site-packages/neo4j/io/__init__.py in _secure(s, host, ssl_context)
#     954             sni_host = host if HAS_SNI and host else None
# --> 955             s = ssl_context.wrap_socket(s, server_hostname=sni_host)
#     956         except (SSLError, OSError) as cause:
#
# /usr/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#
# ...

# %%
plt.rcParams["figure.figsize"] = (16,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014', 'ROB_VOWA_505_Design0013']

norm_opt = [norm_list[i] for i in [2, 5, 10]]
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, m=10, plt3='y')

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014']

norm_opt = [norm_list[i] for i in [2, 5, 10]]
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, m=10, plt3='y')

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014', 'ROB_VOWA_742_Design0013']

norm_opt = [norm_list[i] for i in [2, 5, 10]]
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, m=10)

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014', 'ROB_VOWA_742_Design0013']

norm_opt = [norm_list[i] for i in [2, 5, 10]]
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, m=10, plt3='y')
# Out:
# [2.80068944e+08 9.99809941e-04 1.19999878e-01]
# [2.80068944e+08 9.99809941e-04 1.19000068e-01]
# [2.80068944e+08 9.99809941e-04 1.19999878e-01]
# [2.80068944e+08 9.99809941e-04 1.19000068e-01]

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014']

norm_opt = []
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, m=606, plt3='y')

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014','ROB_VOWA_742_Design0013']

norm_opt = []
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, m=6, plt3='y')

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014','ROB_VOWA_505_Design0013']

norm_opt = []
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, m=6, plt3='y')

# %%
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams.update({'font.size': 12})


nrmList = 'ROB_VOWA_.*'
simList = ['ROB_VOWA_505_Design0014']

norm_opt = []
ft_opt = [feat_list[i] for i in [0, 1, 3]]

sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
cy.plt_nrg_embed(sims_nrg, sims_pid, plt3='y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-403799725480> in <module>
#       9 ft_opt = [feat_list[i] for i in [0, 1, 3]]
#      10
# ---> 11 sims_nrg, sims_pid = cy.feed_normalization(nrmList, simList, norm_opt, ft_opt)
#      12 cy.plt_nrg_embed(sims_nrg, sims_pid, plt3='y')
#
# NameError: name 'cy' is not defined
